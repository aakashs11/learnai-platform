# %% [markdown]
# # Lesson 14 – Capstone: Presentation Notes
# Objectives:
# - Summarize the project.
# - Draft speaking notes and slide structure.

# %% [markdown]
# Draft your final speaking notes here.
#
# Sections:
# 1. Problem & motivation
# 2. Data & method
# 3. Key results (with 1–2 metrics)
# 4. Visuals you will show
# 5. Limitations & future work
