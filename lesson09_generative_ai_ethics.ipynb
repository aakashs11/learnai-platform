# %% [markdown]
# # Lesson 9 – Generative AI Ethics & Scenarios
# Based on Unit 7 (pp. 136–145).
#
# Objectives:
# - Explore ethical scenarios around GenAI.
# - Reflect on risks like deepfakes, bias, copyright.

# %% [markdown]
# ## Reflection prompts
# 1. How could deepfakes affect trust in news?
# 2. When is it acceptable to train on publicly available data?
# 3. How should we credit human creators when using GenAI?
