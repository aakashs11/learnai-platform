# %% [markdown]
# # Lesson 6 – Orange Tool + Big Data Overview
# Based on Unit 4 (pp. 65–85) and Unit 5 (pp. 86–102).
#
# Objectives:
# - Understand Orange as a visual tool (documented, no coding required here).
# - Understand Big Data types and basic analytics types.

# %% [markdown]
# This notebook mainly documents what you would do in Orange and how Big Data is categorized.
#
# ### Big Data types example
# - Structured: table of students and marks
# - Semi-structured: JSON logs
# - Unstructured: images, videos, free text
