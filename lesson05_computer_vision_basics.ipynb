# %% [markdown]
# # Lesson 5 – Computer Vision Basics
# Based on Unit 3 (pp. 43–64).
#
# Objectives:
# - Understand pixels and image representation.
# - Do a couple of basic image operations.

# %% [markdown]
# We will simulate image operations using NumPy arrays (no external images needed).

# %%
import numpy as np

# Simulate a 4x4 grayscale image
img = np.array([
    [  0,  50, 100, 150],
    [ 30,  80, 130, 180],
    [ 60, 110, 160, 210],
    [ 90, 140, 190, 240]
], dtype=np.uint8)
img
