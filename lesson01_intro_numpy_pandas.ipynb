# %% [markdown]
# # Lesson 1 – Intro & Python Libraries (NumPy, Pandas)
# Based on Unit 1 (pp. 1–6) of the Class XII AI handbook.
#
# Objectives:
# - Recall why we use libraries in Python.
# - Recap NumPy arrays and basic Pandas structures.

# %%
import numpy as np
import pandas as pd

# Example: create a NumPy array
a = np.array([1, 2, 3])
a

# %%
# Example: create a DataFrame from a dictionary
data = {'Name': ['Aman', 'Beena', 'Chirag'], 'Marks': [85, 92, 78]}
df = pd.DataFrame(data)
df
