# %% [markdown]
# # Lesson 11 – Capstone: Problem, Data, Plan
# Uses DS methodology material.
#
# Objectives:
# - Define a capstone problem.
# - Specify data and evaluation metric.

# %% [markdown]
# Use this notebook as a planning space.
#
# ## Template
# - Problem statement:
# - Why it matters:
# - Input data:
# - Target variable:
# - Metric(s):
# - Risks/limitations:
